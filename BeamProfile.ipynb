# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Load mat file

# %%
data = loadmat('b.mat')
beam = data['profiledata']
plt.imshow(beam)

# %%
def norm(data):
    maxValue = np.max(data)
    normData = [i/maxValue for i in data]
    return normData

# %%
xprof = norm(beam.sum(axis=0))
yprof = norm(beam.sum(axis=1))

plt.plot(xprof)
plt.show()
plt.plot(yprof)
plt.show()

# %%
def getcentroifd(data):
    avg_val = 0
    sum_val = 0
    
    axis_data = np.linspace(0, len(data), num=len(data))
    
    for i in range(len(data)):
        avg_val = avg_val + axis_data[i] * data[i]
        sum_val = sum_val + data[i]
        
    return avg_val/sum_val

# %%
getcentroifd(xprof)
# Out:
# 476.51333068461855

# %%
len(norm_xprof)
# Out:
# 1032

# %%
-14.66 + getcentroifd(norm_xprof)*0.02841
# Out:
# -1.1222562752499865

# %%
xData = np.linspace(0, len(norm_xprof), num=len(norm_xprof))

cleanx_prof = []

for x, w in zip(xData, norm_xprof):
    if x > 375 and x < 520:
        cleanx_prof.append(w)
    else:
        cleanx_prof.append(0)

-14.66 + getcentroifd(cleanx_prof)*0.02841
# Out:
# -1.9510447834618585

# %%
plt.plot(cleanx_prof)

# %%
-14.66 + getcentroifd(cleanx_prof)*0.02841
# Out:
# -1.9510447834618585

# %%
getcentroifd(cleanx_prof)
# Out:
# 447.34090871306375

# %%
plt.plot(norm_xprof)
